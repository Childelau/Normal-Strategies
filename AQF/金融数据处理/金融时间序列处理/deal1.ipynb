# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import baostock as bs
import warnings; warnings.simplefilter('ignore')

# %%
lg = bs.login()
# Out:
# login success!

# %%
hs300 = bs.query_history_k_data_plus('sh.000300','date,code,open,high,low,close,volume,amount,pctChg', start_date='2020-02-03',end_date='2020-02-20',frequency='d')
temp_list = []
while(hs300.error_code == '0') & hs300.next():
    temp_list.append(hs300.get_row_data())
hs300_res = pd.DataFrame(temp_list,columns = hs300.fields)

print(hs300_res)
# Out:
# date       code       open       high        low      close  \
# 0   2020-02-03  sh.000300  3639.9080  3732.1570  3639.9080  3688.3570
# 1   2020-02-04  sh.000300  3652.0030  3786.8620  3652.0030  3785.6370
# 2   2020-02-05  sh.000300  3801.0990  3866.0100  3781.6130  3828.5270
# 3   2020-02-06  sh.000300  3841.7530  3914.9150  3806.9600  3899.7750
# 4   2020-02-07  sh.000300  3879.5530  3899.8830  3849.7120  3899.8690
# 5   2020-02-10  sh.000300  3872.3730  3920.1660  3861.0060  3916.0050
# 6   2020-02-11  sh.000300  3926.4200  3970.5220  3915.7070  3952.4640
# 7   2020-02-12  sh.000300  3945.6660  3984.4320  3940.6660  3984.4320
# 8   2020-02-13  sh.000300  3985.8750  3999.5490  3950.1420  3959.9180
# 9   2020-02-14  sh.000300  3954.2340  4001.5620  3954.0230  3987.7340
# 10  2020-02-17  sh.000300  3999.6510  4077.4460  3999.6510  4077.4240
# 11  2020-02-18  sh.000300  4069.8310  4076.3880  4027.7850  4057.5100
# ...

# %%
hs300_res['date'] = pd.to_datetime(hs300_res['date'])

# %%
hs300_res.head()
# Out:
#         date       code       open       high        low      close  \
# 0 2020-02-03  sh.000300  3639.9080  3732.1570  3639.9080  3688.3570
# 1 2020-02-04  sh.000300  3652.0030  3786.8620  3652.0030  3785.6370
# 2 2020-02-05  sh.000300  3801.0990  3866.0100  3781.6130  3828.5270
# 3 2020-02-06  sh.000300  3841.7530  3914.9150  3806.9600  3899.7750
# 4 2020-02-07  sh.000300  3879.5530  3899.8830  3849.7120  3899.8690
#
#         volume             amount     pctChg
# 0  15755964672  243303104512.0000  -7.880914
# 1  21393332736  298165768192.0000   2.637489
# 2  17492552448  264042921984.0000   1.132967
# 3  17646223616  262820089856.0000   1.860977
# 4  15173175808  237508816896.0000   0.002410

# %%
hs300_res.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 9 columns):
# date      14 non-null datetime64[ns]
# code      14 non-null object
# open      14 non-null object
# high      14 non-null object
# low       14 non-null object
# close     14 non-null object
# volume    14 non-null object
# amount    14 non-null object
# pctChg    14 non-null object
# dtypes: datetime64[ns](1), object(8)
# memory usage: 1.1+ KB

# %%
hs300_res.head()
# Out:
#         date       code       open       high        low      close  \
# 0 2020-02-03  sh.000300  3639.9080  3732.1570  3639.9080  3688.3570
# 1 2020-02-04  sh.000300  3652.0030  3786.8620  3652.0030  3785.6370
# 2 2020-02-05  sh.000300  3801.0990  3866.0100  3781.6130  3828.5270
# 3 2020-02-06  sh.000300  3841.7530  3914.9150  3806.9600  3899.7750
# 4 2020-02-07  sh.000300  3879.5530  3899.8830  3849.7120  3899.8690
#
#         volume             amount     pctChg
# 0  15755964672  243303104512.0000  -7.880914
# 1  21393332736  298165768192.0000   2.637489
# 2  17492552448  264042921984.0000   1.132967
# 3  17646223616  262820089856.0000   1.860977
# 4  15173175808  237508816896.0000   0.002410

# %%
hs300_res.set_index('date', inplace=True)

# %%
hs300_res['close'].astype('float').plot()

# %%
hs300_res[['close','pctChg']].astype(float).plot(subplots = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000230C1349B00>,
# ...
#       dtype=object)
